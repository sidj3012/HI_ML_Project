# %% [markdown]
# # loading dataset

# %%
import os
import numpy as np
import wave
from pathlib import Path

def convert_wav_to_array(wav_path):
    """
    Convert a WAV file to a numpy array and return its sampling rate.
    
    Args:
        wav_path (str): Path to the WAV file
        
    Returns:
        tuple: (audio_array, sampling_rate)
        - audio_array: numpy array containing the audio data
        - sampling_rate: integer representing the sampling rate of the audio
    """
    try:
        with wave.open(wav_path, 'rb') as wav_file:
            # Get sampling rate and number of frames
            sampling_rate = wav_file.getframerate()
            n_frames = wav_file.getnframes()
            
            # Read the frames
            signal = wav_file.readframes(n_frames)
            
            # Convert to numpy array
            audio_array = np.frombuffer(signal, dtype=np.int16)
            
            # If stereo, convert to mono by averaging channels
            if wav_file.getnchannels() == 2:
                audio_array = audio_array.reshape(-1, 2).mean(axis=1)
            
            return audio_array, sampling_rate
    except Exception as e:
        print(f"Error processing {wav_path}: {str(e)}")
        return None, None

def process_wav_directory(directory_path):
    """
    Process all WAV files in a directory.
    
    Args:
        directory_path (str): Path to directory containing WAV files
        
    Returns:
        dict: Dictionary with wav filenames as keys and tuples of (audio_array, sampling_rate) as values
    """
    results = {}
    wav_files = Path(directory_path).glob('*.wav')
    
    for wav_path in wav_files:
        audio_array, sampling_rate = convert_wav_to_array(str(wav_path))
        if audio_array is not None:
            results[wav_path.name] = (audio_array, sampling_rate)
            print(f"Processed {wav_path.name} - Sampling Rate: {sampling_rate} Hz")
    
    return results

# Example usage
if __name__ == "__main__":
   
    
    # Process all WAV files in a directory
    directory_path = "data/audio_files"
    results = process_wav_directory(directory_path)
# Out:
# Processed 1184-121024-0021.wav - Sampling Rate: 16000 Hz
# Processed 1184-121024-0037.wav - Sampling Rate: 16000 Hz
# Processed 1184-121024-0090.wav - Sampling Rate: 16000 Hz
# Processed 1184-121024-0158.wav - Sampling Rate: 16000 Hz
# Processed 1184-121024-0159.wav - Sampling Rate: 16000 Hz
# Processed 1184-121024-0160.wav - Sampling Rate: 16000 Hz
# Processed 1184-121024-0162.wav - Sampling Rate: 16000 Hz
# Processed 1184-121024-0172.wav - Sampling Rate: 16000 Hz
# Processed 1184-121024-0173.wav - Sampling Rate: 16000 Hz
# Processed 1184-121024-0178.wav - Sampling Rate: 16000 Hz
# Processed 1184-121045-0004.wav - Sampling Rate: 16000 Hz
# Processed 1184-121045-0012.wav - Sampling Rate: 16000 Hz
# Processed 1184-121045-0017.wav - Sampling Rate: 16000 Hz
# Processed 1184-121045-0018.wav - Sampling Rate: 16000 Hz
# Processed 1184-121045-0024.wav - Sampling Rate: 16000 Hz
# Processed 1184-121045-0034.wav - Sampling Rate: 16000 Hz
# Processed 1184-121045-0035.wav - Sampling Rate: 16000 Hz
# Processed 1184-121045-0047.wav - Sampling Rate: 16000 Hz
# Processed 1184-121045-0053.wav - Sampling Rate: 16000 Hz
# Processed 1184-121045-0062.wav - Sampling Rate: 16000 Hz
# Processed 1184-121045-0066.wav - Sampling Rate: 16000 Hz
# Processed 1184-121045-0077.wav - Sampling Rate: 16000 Hz
# Processed 1184-121045-0080.wav - Sampling Rate: 16000 Hz
# Processed 1184-121050-0010.wav - Sampling Rate: 16000 Hz
# Processed 1184-121050-0018.wav - Sampling Rate: 16000 Hz
# Processed 1184-121050-0027.wav - Sampling Rate: 16000 Hz
# Processed 1184-121050-0029.wav - Sampling Rate: 16000 Hz
# Processed 1184-121050-0032.wav - Sampling Rate: 16000 Hz
# Processed 1184-121050-0034.wav - Sampling Rate: 16000 Hz
# Processed 1184-121050-0035.wav - Sampling Rate: 16000 Hz
# Processed 1184-121050-0036.wav - Sampling Rate: 16000 Hz
# Processed 1184-121050-0042.wav - Sampling Rate: 16000 Hz
# Processed 1184-121050-0052.wav - Sampling Rate: 16000 Hz
# Processed 1184-121050-0054.wav - Sampling Rate: 16000 Hz
# Processed 1184-121050-0059.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0003.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0005.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0006.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0008.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0012.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0024.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0033.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0039.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0043.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0047.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0057.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0063.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0077.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0083.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0084.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0087.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0099.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0117.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0123.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0127.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0147.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0150.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0163.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0170.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0184.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0199.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0208.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0214.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0215.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0231.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0234.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0237.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0240.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0258.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0268.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0270.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0281.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0289.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0294.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0295.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0296.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0297.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0311.wav - Sampling Rate: 16000 Hz
# Processed 1184-121052-0315.wav - Sampling Rate: 16000 Hz
# Processed 1184-121055-0143.wav - Sampling Rate: 16000 Hz
# Processed 1184-121055-0146.wav - Sampling Rate: 16000 Hz
# Processed 1184-121055-0149.wav - Sampling Rate: 16000 Hz
# Processed 1184-121055-0156.wav - Sampling Rate: 16000 Hz
# Processed 1184-121055-0157.wav - Sampling Rate: 16000 Hz
# Processed 1184-121055-0162.wav - Sampling Rate: 16000 Hz
# Processed 1184-121055-0167.wav - Sampling Rate: 16000 Hz
# Processed 1184-121055-0186.wav - Sampling Rate: 16000 Hz
# Processed 1184-121055-0189.wav - Sampling Rate: 16000 Hz
# Processed 1184-121055-0204.wav - Sampling Rate: 16000 Hz
# Processed 1184-121055-0229.wav - Sampling Rate: 16000 Hz
# Processed 1184-121055-0243.wav - Sampling Rate: 16000 Hz
# Processed 1184-121055-0257.wav - Sampling Rate: 16000 Hz
# Processed 1184-121055-0278.wav - Sampling Rate: 16000 Hz
# Processed 1184-121057-0009.wav - Sampling Rate: 16000 Hz
# Processed 1184-121057-0035.wav - Sampling Rate: 16000 Hz
# Processed 1184-121057-0059.wav - Sampling Rate: 16000 Hz
# Processed 1184-121057-0067.wav - Sampling Rate: 16000 Hz
# Processed 1184-121057-0068.wav - Sampling Rate: 16000 Hz
# Processed 1184-121057-0069.wav - Sampling Rate: 16000 Hz
# Processed 1184-121057-0070.wav - Sampling Rate: 16000 Hz
# Processed 1184-121057-0081.wav - Sampling Rate: 16000 Hz
# Processed 1184-121064-0005.wav - Sampling Rate: 16000 Hz
# Processed 1184-121064-0007.wav - Sampling Rate: 16000 Hz
# Processed 1184-121064-0009.wav - Sampling Rate: 16000 Hz
# Processed 1184-121064-0058.wav - Sampling Rate: 16000 Hz
# Processed 1184-121064-0069.wav - Sampling Rate: 16000 Hz
# Processed 1184-121064-0074.wav - Sampling Rate: 16000 Hz
# Processed 1184-121064-0076.wav - Sampling Rate: 16000 Hz
# Processed 1184-121064-0158.wav - Sampling Rate: 16000 Hz
# Processed 1184-121064-0163.wav - Sampling Rate: 16000 Hz
# Processed 1184-121064-0171.wav - Sampling Rate: 16000 Hz
# Processed 1184-121074-0005.wav - Sampling Rate: 16000 Hz
# Processed 1184-121074-0006.wav - Sampling Rate: 16000 Hz
# Processed 1184-121074-0009.wav - Sampling Rate: 16000 Hz
# Processed 1184-121074-0016.wav - Sampling Rate: 16000 Hz
# Processed 1184-121074-0018.wav - Sampling Rate: 16000 Hz
# Processed 1184-121074-0033.wav - Sampling Rate: 16000 Hz
# Processed 1184-121074-0035.wav - Sampling Rate: 16000 Hz
# Processed 1184-121074-0042.wav - Sampling Rate: 16000 Hz
# Processed 1184-121074-0066.wav - Sampling Rate: 16000 Hz
# Processed 1184-121074-0090.wav - Sampling Rate: 16000 Hz
# Processed 1184-121074-0093.wav - Sampling Rate: 16000 Hz
# Processed 1184-121074-0094.wav - Sampling Rate: 16000 Hz
# Processed 1184-121074-0115.wav - Sampling Rate: 16000 Hz
# Processed 1184-121074-0128.wav - Sampling Rate: 16000 Hz
# Processed 1184-121074-0138.wav - Sampling Rate: 16000 Hz
# Processed 1184-121074-0143.wav - Sampling Rate: 16000 Hz
# Processed 1184-121074-0147.wav - Sampling Rate: 16000 Hz
# Processed 1184-121074-0150.wav - Sampling Rate: 16000 Hz
# Processed 1184-121074-0151.wav - Sampling Rate: 16000 Hz
# Processed 1184-121074-0173.wav - Sampling Rate: 16000 Hz
# Processed 1184-121074-0191.wav - Sampling Rate: 16000 Hz
# Processed 1184-121074-0215.wav - Sampling Rate: 16000 Hz
# Processed 1184-121074-0223.wav - Sampling Rate: 16000 Hz
# Processed 1184-121074-0225.wav - Sampling Rate: 16000 Hz
# Processed 1184-121074-0227.wav - Sampling Rate: 16000 Hz
# Processed 1184-121075-0001.wav - Sampling Rate: 16000 Hz
# Processed 1184-121075-0004.wav - Sampling Rate: 16000 Hz
# Processed 1184-121075-0018.wav - Sampling Rate: 16000 Hz
# Processed 1184-121075-0020.wav - Sampling Rate: 16000 Hz
# Processed 1184-121075-0026.wav - Sampling Rate: 16000 Hz
# Processed 1184-121075-0044.wav - Sampling Rate: 16000 Hz
# Processed 1184-121075-0049.wav - Sampling Rate: 16000 Hz
# Processed 1184-121075-0057.wav - Sampling Rate: 16000 Hz
# Processed 1184-121075-0078.wav - Sampling Rate: 16000 Hz
# Processed 1184-121075-0091.wav - Sampling Rate: 16000 Hz
# Processed 1184-121075-0110.wav - Sampling Rate: 16000 Hz
# Processed 1184-121075-0161.wav - Sampling Rate: 16000 Hz
# Processed 1184-121075-0163.wav - Sampling Rate: 16000 Hz
# Processed 1184-121081-0004.wav - Sampling Rate: 16000 Hz
# Processed 1184-121081-0008.wav - Sampling Rate: 16000 Hz
# Processed 1184-121081-0017.wav - Sampling Rate: 16000 Hz
# Processed 1184-121081-0018.wav - Sampling Rate: 16000 Hz
# Processed 1184-121081-0019.wav - Sampling Rate: 16000 Hz
# Processed 1184-121081-0023.wav - Sampling Rate: 16000 Hz
# Processed 1184-121081-0024.wav - Sampling Rate: 16000 Hz
# Processed 1184-121081-0025.wav - Sampling Rate: 16000 Hz
# Processed 1184-121081-0026.wav - Sampling Rate: 16000 Hz
# Processed 1184-121081-0028.wav - Sampling Rate: 16000 Hz
# Processed 1184-121081-0037.wav - Sampling Rate: 16000 Hz
# Processed 1184-121081-0038.wav - Sampling Rate: 16000 Hz
# Processed 1184-121081-0067.wav - Sampling Rate: 16000 Hz
# Processed 1184-121081-0073.wav - Sampling Rate: 16000 Hz
# Processed 1184-121081-0077.wav - Sampling Rate: 16000 Hz
# Processed 1184-121081-0098.wav - Sampling Rate: 16000 Hz
# Processed 1184-121081-0106.wav - Sampling Rate: 16000 Hz
# Processed 1184-121081-0107.wav - Sampling Rate: 16000 Hz
# Processed 1184-121082-0001.wav - Sampling Rate: 16000 Hz
# Processed 1184-121082-0003.wav - Sampling Rate: 16000 Hz
# Processed 1184-121082-0011.wav - Sampling Rate: 16000 Hz
# Processed 1184-121082-0017.wav - Sampling Rate: 16000 Hz
# Processed 1184-121082-0024.wav - Sampling Rate: 16000 Hz
# Processed 1184-121082-0060.wav - Sampling Rate: 16000 Hz
# Processed 1184-121082-0083.wav - Sampling Rate: 16000 Hz
# Processed 1184-121082-0084.wav - Sampling Rate: 16000 Hz
# Processed 1184-121082-0107.wav - Sampling Rate: 16000 Hz
# Processed 1184-121082-0115.wav - Sampling Rate: 16000 Hz
# Processed 1184-121082-0118.wav - Sampling Rate: 16000 Hz
# Processed 1184-121082-0134.wav - Sampling Rate: 16000 Hz
# Processed 1184-121082-0156.wav - Sampling Rate: 16000 Hz
# Processed 1184-121084-0005.wav - Sampling Rate: 16000 Hz
# Processed 1184-121084-0024.wav - Sampling Rate: 16000 Hz
# Processed 1184-121084-0027.wav - Sampling Rate: 16000 Hz
# Processed 1184-121084-0034.wav - Sampling Rate: 16000 Hz
# Processed 1184-121084-0045.wav - Sampling Rate: 16000 Hz
# Processed 1184-121084-0052.wav - Sampling Rate: 16000 Hz
# Processed 1184-121084-0055.wav - Sampling Rate: 16000 Hz
# Processed 1184-121084-0067.wav - Sampling Rate: 16000 Hz
# Processed 1184-121084-0079.wav - Sampling Rate: 16000 Hz
# Processed 1184-121084-0083.wav - Sampling Rate: 16000 Hz
# Processed 1184-121084-0084.wav - Sampling Rate: 16000 Hz
# Processed 1184-121084-0090.wav - Sampling Rate: 16000 Hz
# Processed 1184-121084-0092.wav - Sampling Rate: 16000 Hz
# Processed 1184-121084-0106.wav - Sampling Rate: 16000 Hz
# Processed 1184-121084-0111.wav - Sampling Rate: 16000 Hz
# Processed 1184-121084-0113.wav - Sampling Rate: 16000 Hz
# Processed 1184-121084-0115.wav - Sampling Rate: 16000 Hz
# Processed 1184-121084-0143.wav - Sampling Rate: 16000 Hz
# Processed 1184-121084-0152.wav - Sampling Rate: 16000 Hz
# Processed 1184-121084-0157.wav - Sampling Rate: 16000 Hz
# Processed 1184-121084-0159.wav - Sampling Rate: 16000 Hz
# Processed 1184-121084-0162.wav - Sampling Rate: 16000 Hz
# Processed 1184-121084-0173.wav - Sampling Rate: 16000 Hz
# Processed 1184-121084-0175.wav - Sampling Rate: 16000 Hz
# Processed 1184-121085-0003.wav - Sampling Rate: 16000 Hz
# Processed 1184-121085-0004.wav - Sampling Rate: 16000 Hz
# Processed 1184-121085-0017.wav - Sampling Rate: 16000 Hz
# Processed 1184-121085-0028.wav - Sampling Rate: 16000 Hz
# Processed 1184-121089-0038.wav - Sampling Rate: 16000 Hz
# Processed 1184-121089-0049.wav - Sampling Rate: 16000 Hz
# Processed 1184-121090-0042.wav - Sampling Rate: 16000 Hz
# Processed 1184-121090-0050.wav - Sampling Rate: 16000 Hz
# Processed 1184-121090-0089.wav - Sampling Rate: 16000 Hz
# Processed 1184-121090-0092.wav - Sampling Rate: 16000 Hz
# Processed 1184-121090-0094.wav - Sampling Rate: 16000 Hz
# Processed 1184-121090-0095.wav - Sampling Rate: 16000 Hz
# Processed 1184-121090-0098.wav - Sampling Rate: 16000 Hz
# Processed 1184-121090-0105.wav - Sampling Rate: 16000 Hz
# Processed 1184-121090-0106.wav - Sampling Rate: 16000 Hz
# Processed 1184-121090-0120.wav - Sampling Rate: 16000 Hz
# Processed 1184-121090-0125.wav - Sampling Rate: 16000 Hz
# Processed 1184-121090-0151.wav - Sampling Rate: 16000 Hz
# Processed 1184-121090-0175.wav - Sampling Rate: 16000 Hz
# Processed 1184-121090-0186.wav - Sampling Rate: 16000 Hz
# Processed 1184-121103-0001.wav - Sampling Rate: 16000 Hz
# Processed 1184-121103-0012.wav - Sampling Rate: 16000 Hz
# Processed 1184-121103-0019.wav - Sampling Rate: 16000 Hz
# Processed 1184-121103-0022.wav - Sampling Rate: 16000 Hz
# Processed 1184-121103-0040.wav - Sampling Rate: 16000 Hz
# Processed 1184-121103-0044.wav - Sampling Rate: 16000 Hz
# Processed 1184-121103-0055.wav - Sampling Rate: 16000 Hz
# Processed 1184-121103-0056.wav - Sampling Rate: 16000 Hz
# Processed 1184-121103-0061.wav - Sampling Rate: 16000 Hz
# Processed 1184-121103-0081.wav - Sampling Rate: 16000 Hz
# Processed 1184-121106-0015.wav - Sampling Rate: 16000 Hz
# Processed 1184-121106-0018.wav - Sampling Rate: 16000 Hz
# Processed 1184-121106-0052.wav - Sampling Rate: 16000 Hz
# Processed 1184-121106-0054.wav - Sampling Rate: 16000 Hz
# Processed 1184-121106-0060.wav - Sampling Rate: 16000 Hz
# Processed 1184-121106-0075.wav - Sampling Rate: 16000 Hz
# Processed 1184-121106-0079.wav - Sampling Rate: 16000 Hz
# Processed 1184-121106-0084.wav - Sampling Rate: 16000 Hz
# Processed 1184-121119-0006.wav - Sampling Rate: 16000 Hz
# Processed 1184-121119-0022.wav - Sampling Rate: 16000 Hz
# Processed 1184-121119-0032.wav - Sampling Rate: 16000 Hz
# Processed 1184-121119-0046.wav - Sampling Rate: 16000 Hz
# Processed 1184-121119-0049.wav - Sampling Rate: 16000 Hz
# Processed 1184-121119-0064.wav - Sampling Rate: 16000 Hz
# Processed 1184-121119-0066.wav - Sampling Rate: 16000 Hz
# Processed 1184-121119-0095.wav - Sampling Rate: 16000 Hz
# Processed 1184-121124-0024.wav - Sampling Rate: 16000 Hz
# Processed 1184-121124-0031.wav - Sampling Rate: 16000 Hz
# Processed 1184-121124-0039.wav - Sampling Rate: 16000 Hz
# Processed 1184-121124-0040.wav - Sampling Rate: 16000 Hz
# Processed 1184-121124-0056.wav - Sampling Rate: 16000 Hz
# Processed 1184-121124-0094.wav - Sampling Rate: 16000 Hz
# Processed 1184-121124-0098.wav - Sampling Rate: 16000 Hz
# Processed 1184-121124-0102.wav - Sampling Rate: 16000 Hz
# Processed 1184-121124-0105.wav - Sampling Rate: 16000 Hz
# Processed 1184-121124-0120.wav - Sampling Rate: 16000 Hz
# Processed 1184-121124-0124.wav - Sampling Rate: 16000 Hz
# Processed 1184-121124-0135.wav - Sampling Rate: 16000 Hz
# Processed 1184-121124-0136.wav - Sampling Rate: 16000 Hz
# Processed 1184-121124-0146.wav - Sampling Rate: 16000 Hz
# Processed 1184-121124-0156.wav - Sampling Rate: 16000 Hz
# Processed 1184-121124-0170.wav - Sampling Rate: 16000 Hz
# Processed 1184-121124-0171.wav - Sampling Rate: 16000 Hz
# Processed 1184-289242-0006.wav - Sampling Rate: 16000 Hz
# Processed 1184-289242-0014.wav - Sampling Rate: 16000 Hz
# Processed 1184-289242-0022.wav - Sampling Rate: 16000 Hz
# Processed 1184-289242-0036.wav - Sampling Rate: 16000 Hz
# Processed 1184-289242-0046.wav - Sampling Rate: 16000 Hz
# Processed 1184-289242-0050.wav - Sampling Rate: 16000 Hz
# Processed 1184-289242-0054.wav - Sampling Rate: 16000 Hz
# Processed 1184-289242-0062.wav - Sampling Rate: 16000 Hz
# Processed 1184-289242-0078.wav - Sampling Rate: 16000 Hz
# Processed 1184-289242-0081.wav - Sampling Rate: 16000 Hz
# Processed 1184-86708-0002.wav - Sampling Rate: 16000 Hz
# Processed 1184-86708-0003.wav - Sampling Rate: 16000 Hz
# Processed 1184-86708-0004.wav - Sampling Rate: 16000 Hz
# Processed 1184-86708-0009.wav - Sampling Rate: 16000 Hz
# Processed 1184-86708-0029.wav - Sampling Rate: 16000 Hz
# Processed 1184-86708-0031.wav - Sampling Rate: 16000 Hz
# Processed 1184-86708-0051.wav - Sampling Rate: 16000 Hz
# Processed 1184-86708-0057.wav - Sampling Rate: 16000 Hz
# Processed 1184-86708-0060.wav - Sampling Rate: 16000 Hz
# Processed 1184-86708-0063.wav - Sampling Rate: 16000 Hz
# Processed 1184-86708-0064.wav - Sampling Rate: 16000 Hz
# Processed 1184-86708-0065.wav - Sampling Rate: 16000 Hz
# Processed 1184-86708-0077.wav - Sampling Rate: 16000 Hz
# Processed 1184-86708-0081.wav - Sampling Rate: 16000 Hz
# Processed 1184-86708-0101.wav - Sampling Rate: 16000 Hz
# Processed 1184-86710-0000.wav - Sampling Rate: 16000 Hz
# Processed 1184-86710-0001.wav - Sampling Rate: 16000 Hz
# Processed 1184-86710-0006.wav - Sampling Rate: 16000 Hz
# Processed 1184-86710-0030.wav - Sampling Rate: 16000 Hz
# Processed 1184-86710-0041.wav - Sampling Rate: 16000 Hz
# Processed 1184-86710-0044.wav - Sampling Rate: 16000 Hz
# Processed 1184-86710-0046.wav - Sampling Rate: 16000 Hz
# Processed 1184-86710-0048.wav - Sampling Rate: 16000 Hz
# Processed 1184-86710-0050.wav - Sampling Rate: 16000 Hz
# Processed 1184-86710-0080.wav - Sampling Rate: 16000 Hz
# Processed 1184-86710-0084.wav - Sampling Rate: 16000 Hz
# Processed 1184-86710-0090.wav - Sampling Rate: 16000 Hz
# Processed 1184-86710-0105.wav - Sampling Rate: 16000 Hz
# Processed 1184-86710-0106.wav - Sampling Rate: 16000 Hz
# Processed 1184-86712-0000.wav - Sampling Rate: 16000 Hz
# Processed 1184-86712-0009.wav - Sampling Rate: 16000 Hz
# Processed 1184-86712-0051.wav - Sampling Rate: 16000 Hz
# Processed 1184-86712-0065.wav - Sampling Rate: 16000 Hz
# Processed 1184-86712-0066.wav - Sampling Rate: 16000 Hz
# Processed 1184-86712-0092.wav - Sampling Rate: 16000 Hz
# Processed 1184-86712-0094.wav - Sampling Rate: 16000 Hz
# Processed 1184-86712-0141.wav - Sampling Rate: 16000 Hz
# Processed 1184-86713-0015.wav - Sampling Rate: 16000 Hz
# Processed 1184-86713-0019.wav - Sampling Rate: 16000 Hz
# Processed 1184-86713-0066.wav - Sampling Rate: 16000 Hz
# Processed 1184-86713-0072.wav - Sampling Rate: 16000 Hz
# Processed 1184-86713-0077.wav - Sampling Rate: 16000 Hz
# Processed 1184-86732-0002.wav - Sampling Rate: 16000 Hz
# Processed 1184-86732-0003.wav - Sampling Rate: 16000 Hz
# Processed 1184-86732-0009.wav - Sampling Rate: 16000 Hz
# Processed 1184-86732-0029.wav - Sampling Rate: 16000 Hz
# Processed 1184-86732-0060.wav - Sampling Rate: 16000 Hz
# Processed 1184-86732-0084.wav - Sampling Rate: 16000 Hz
# Processed 1184-86737-0010.wav - Sampling Rate: 16000 Hz
# Processed 1184-86737-0061.wav - Sampling Rate: 16000 Hz
# Processed 1184-86737-0077.wav - Sampling Rate: 16000 Hz
# Processed 1184-86737-0082.wav - Sampling Rate: 16000 Hz
# Processed 1184-86737-0085.wav - Sampling Rate: 16000 Hz
# Processed 1184-86737-0087.wav - Sampling Rate: 16000 Hz
# Processed 1184-86737-0097.wav - Sampling Rate: 16000 Hz
# Processed 1184-86737-0098.wav - Sampling Rate: 16000 Hz
# Processed 1184-86737-0102.wav - Sampling Rate: 16000 Hz
# Processed 1184-86737-0107.wav - Sampling Rate: 16000 Hz
# Processed 1184-86737-0110.wav - Sampling Rate: 16000 Hz
# Processed 1184-86737-0118.wav - Sampling Rate: 16000 Hz
# Processed 1184-86737-0120.wav - Sampling Rate: 16000 Hz
# Processed 1184-86737-0143.wav - Sampling Rate: 16000 Hz
# Processed 1184-86737-0145.wav - Sampling Rate: 16000 Hz
# Processed 1184-86737-0147.wav - Sampling Rate: 16000 Hz
# Processed 1184-86737-0162.wav - Sampling Rate: 16000 Hz
# Processed 1184-86737-0165.wav - Sampling Rate: 16000 Hz
# Processed 1184-86737-0169.wav - Sampling Rate: 16000 Hz
# Processed 1184-86737-0175.wav - Sampling Rate: 16000 Hz
# Processed 1184-86737-0176.wav - Sampling Rate: 16000 Hz
# Processed 1184-86737-0200.wav - Sampling Rate: 16000 Hz
# Processed 1184-86737-0238.wav - Sampling Rate: 16000 Hz
# Processed 1184-86741-0000.wav - Sampling Rate: 16000 Hz
# Processed 1184-86741-0008.wav - Sampling Rate: 16000 Hz
# Processed 1184-86741-0026.wav - Sampling Rate: 16000 Hz
# Processed 1184-86741-0029.wav - Sampling Rate: 16000 Hz
# Processed 1184-86741-0032.wav - Sampling Rate: 16000 Hz
# Processed 1184-86741-0033.wav - Sampling Rate: 16000 Hz
# Processed 1184-86741-0034.wav - Sampling Rate: 16000 Hz
# Processed 1184-86741-0035.wav - Sampling Rate: 16000 Hz
# Processed 1184-86741-0036.wav - Sampling Rate: 16000 Hz
# Processed 1184-86741-0043.wav - Sampling Rate: 16000 Hz
# Processed 1184-86741-0051.wav - Sampling Rate: 16000 Hz
# Processed 1184-86741-0053.wav - Sampling Rate: 16000 Hz
# Processed 1184-86741-0055.wav - Sampling Rate: 16000 Hz
# Processed 1184-86741-0072.wav - Sampling Rate: 16000 Hz
# Processed 1184-86741-0076.wav - Sampling Rate: 16000 Hz
# Processed 1184-86741-0077.wav - Sampling Rate: 16000 Hz
# Processed 1184-86741-0081.wav - Sampling Rate: 16000 Hz
# Processed 1184-86741-0091.wav - Sampling Rate: 16000 Hz
# Processed 1184-86741-0092.wav - Sampling Rate: 16000 Hz
# Processed 1184-86741-0104.wav - Sampling Rate: 16000 Hz
# Processed 1184-86741-0127.wav - Sampling Rate: 16000 Hz
# Processed 1184-86741-0131.wav - Sampling Rate: 16000 Hz
# Processed 1184-86741-0139.wav - Sampling Rate: 16000 Hz
# Processed 1184-86741-0140.wav - Sampling Rate: 16000 Hz
# Processed 1184-86741-0172.wav - Sampling Rate: 16000 Hz
# Processed 1184-86741-0174.wav - Sampling Rate: 16000 Hz
# Processed 1184-86746-0144.wav - Sampling Rate: 16000 Hz
# Processed 1184-86746-0148.wav - Sampling Rate: 16000 Hz
# Processed 1184-86746-0158.wav - Sampling Rate: 16000 Hz
# Processed 1184-86746-0174.wav - Sampling Rate: 16000 Hz
# Processed 1184-86746-0186.wav - Sampling Rate: 16000 Hz
# Processed 1184-86746-0188.wav - Sampling Rate: 16000 Hz
# Processed 1184-86746-0209.wav - Sampling Rate: 16000 Hz
# Processed 1184-86746-0223.wav - Sampling Rate: 16000 Hz
# Processed 1184-86746-0224.wav - Sampling Rate: 16000 Hz
# Processed 1184-86746-0226.wav - Sampling Rate: 16000 Hz
# Processed 1184-86746-0228.wav - Sampling Rate: 16000 Hz
# Processed 1184-86746-0235.wav - Sampling Rate: 16000 Hz
# Processed 1184-86746-0237.wav - Sampling Rate: 16000 Hz
# Processed 1184-86746-0241.wav - Sampling Rate: 16000 Hz
# Processed 1184-86746-0242.wav - Sampling Rate: 16000 Hz
# Processed 1184-86746-0261.wav - Sampling Rate: 16000 Hz
# Processed 1184-86748-0009.wav - Sampling Rate: 16000 Hz
# Processed 1184-86748-0036.wav - Sampling Rate: 16000 Hz
# Processed 1184-86748-0064.wav - Sampling Rate: 16000 Hz
# Processed 1184-86748-0072.wav - Sampling Rate: 16000 Hz
# Processed 1184-86748-0073.wav - Sampling Rate: 16000 Hz
# Processed 1184-86748-0074.wav - Sampling Rate: 16000 Hz
# Processed 1184-86748-0075.wav - Sampling Rate: 16000 Hz
# Processed 1184-86748-0077.wav - Sampling Rate: 16000 Hz
# Processed 1184-86748-0085.wav - Sampling Rate: 16000 Hz
# Processed 1184-86765-0008.wav - Sampling Rate: 16000 Hz
# Processed 1184-86765-0022.wav - Sampling Rate: 16000 Hz
# Processed 1184-86765-0033.wav - Sampling Rate: 16000 Hz
# Processed 1184-86765-0041.wav - Sampling Rate: 16000 Hz
# Processed 1184-86765-0059.wav - Sampling Rate: 16000 Hz
# Processed 1184-86765-0074.wav - Sampling Rate: 16000 Hz
# Processed 1184-86765-0104.wav - Sampling Rate: 16000 Hz
# Processed 1184-86765-0106.wav - Sampling Rate: 16000 Hz
# Processed 1184-86765-0119.wav - Sampling Rate: 16000 Hz
# Processed 1184-86765-0133.wav - Sampling Rate: 16000 Hz
# Processed 1184-86776-0016.wav - Sampling Rate: 16000 Hz
# Processed 1184-86776-0025.wav - Sampling Rate: 16000 Hz
# Processed 1184-86776-0055.wav - Sampling Rate: 16000 Hz
# Processed 1184-86776-0056.wav - Sampling Rate: 16000 Hz
# Processed 1184-86776-0057.wav - Sampling Rate: 16000 Hz
# Processed 1184-86776-0062.wav - Sampling Rate: 16000 Hz
# Processed 1184-86776-0068.wav - Sampling Rate: 16000 Hz
# Processed 1184-86776-0072.wav - Sampling Rate: 16000 Hz
# Processed 1184-86776-0079.wav - Sampling Rate: 16000 Hz
# Processed 1184-86776-0081.wav - Sampling Rate: 16000 Hz
# Processed 1184-86776-0089.wav - Sampling Rate: 16000 Hz
# Processed 1184-86776-0098.wav - Sampling Rate: 16000 Hz
# Processed 1184-86776-0103.wav - Sampling Rate: 16000 Hz
# Processed 1184-86776-0104.wav - Sampling Rate: 16000 Hz
# Processed 1184-86776-0117.wav - Sampling Rate: 16000 Hz
# Processed 1184-86776-0129.wav - Sampling Rate: 16000 Hz
# Processed 1184-86776-0131.wav - Sampling Rate: 16000 Hz
# Processed 1184-86776-0151.wav - Sampling Rate: 16000 Hz
# Processed 1184-86776-0157.wav - Sampling Rate: 16000 Hz
# Processed 1184-86777-0041.wav - Sampling Rate: 16000 Hz
# Processed 1184-86777-0052.wav - Sampling Rate: 16000 Hz
# Processed 1184-86777-0080.wav - Sampling Rate: 16000 Hz
# Processed 1184-86779-0010.wav - Sampling Rate: 16000 Hz
# Processed 1184-86779-0011.wav - Sampling Rate: 16000 Hz
# Processed 1184-86779-0031.wav - Sampling Rate: 16000 Hz
# Processed 1184-86779-0054.wav - Sampling Rate: 16000 Hz
# Processed 1184-86779-0063.wav - Sampling Rate: 16000 Hz
# Processed 1184-86779-0065.wav - Sampling Rate: 16000 Hz
# Processed 1184-86787-0003.wav - Sampling Rate: 16000 Hz
# Processed 1184-86787-0009.wav - Sampling Rate: 16000 Hz
# Processed 1184-86787-0017.wav - Sampling Rate: 16000 Hz
# Processed 1184-86787-0021.wav - Sampling Rate: 16000 Hz
# Processed 1184-86787-0026.wav - Sampling Rate: 16000 Hz
# Processed 1184-86787-0046.wav - Sampling Rate: 16000 Hz
# Processed 1184-86787-0048.wav - Sampling Rate: 16000 Hz
# Processed 1184-86787-0070.wav - Sampling Rate: 16000 Hz
# Processed 1184-86787-0074.wav - Sampling Rate: 16000 Hz
# Processed 1184-86787-0075.wav - Sampling Rate: 16000 Hz
# Processed 1184-86794-0019.wav - Sampling Rate: 16000 Hz
# Processed 1184-86794-0041.wav - Sampling Rate: 16000 Hz
# Processed 1184-86794-0042.wav - Sampling Rate: 16000 Hz
# Processed 1184-86794-0047.wav - Sampling Rate: 16000 Hz
# Processed 1184-86794-0058.wav - Sampling Rate: 16000 Hz
# Processed 1184-86794-0071.wav - Sampling Rate: 16000 Hz
# Processed 1184-86794-0094.wav - Sampling Rate: 16000 Hz
# Processed 1184-86794-0098.wav - Sampling Rate: 16000 Hz
# Processed 1184-86804-0001.wav - Sampling Rate: 16000 Hz
# Processed 1184-86804-0003.wav - Sampling Rate: 16000 Hz
# Processed 1184-86804-0008.wav - Sampling Rate: 16000 Hz
# Processed 1184-86804-0012.wav - Sampling Rate: 16000 Hz
# Processed 1184-86804-0023.wav - Sampling Rate: 16000 Hz
# Processed 1184-86804-0034.wav - Sampling Rate: 16000 Hz
# Processed 1184-86804-0057.wav - Sampling Rate: 16000 Hz
# Processed 1184-86804-0061.wav - Sampling Rate: 16000 Hz
# Processed 1184-86804-0065.wav - Sampling Rate: 16000 Hz
# Processed 1184-86804-0073.wav - Sampling Rate: 16000 Hz
# Processed 1184-86804-0090.wav - Sampling Rate: 16000 Hz
# Processed 1184-86804-0098.wav - Sampling Rate: 16000 Hz
# Processed 1184-86809-0053.wav - Sampling Rate: 16000 Hz
# Processed 1184-86809-0060.wav - Sampling Rate: 16000 Hz
# Processed 1184-86809-0063.wav - Sampling Rate: 16000 Hz
# Processed 1184-86814-0003.wav - Sampling Rate: 16000 Hz
# Processed 1184-86814-0018.wav - Sampling Rate: 16000 Hz
# Processed 1184-86814-0025.wav - Sampling Rate: 16000 Hz
# Processed 1184-86814-0048.wav - Sampling Rate: 16000 Hz
# Processed 1184-86814-0079.wav - Sampling Rate: 16000 Hz
# Processed 1184-86814-0086.wav - Sampling Rate: 16000 Hz
# Processed 1184-86815-0036.wav - Sampling Rate: 16000 Hz
# Processed 1184-86815-0043.wav - Sampling Rate: 16000 Hz
# Processed 1184-86815-0078.wav - Sampling Rate: 16000 Hz
# Processed 1184-86815-0110.wav - Sampling Rate: 16000 Hz
# Processed 1184-86822-0009.wav - Sampling Rate: 16000 Hz
# Processed 1184-86822-0032.wav - Sampling Rate: 16000 Hz
# Processed 1184-86822-0040.wav - Sampling Rate: 16000 Hz
# Processed 1184-86822-0055.wav - Sampling Rate: 16000 Hz
# Processed 1184-86822-0067.wav - Sampling Rate: 16000 Hz
# Processed 1184-86822-0068.wav - Sampling Rate: 16000 Hz
# Processed 1184-86822-0070.wav - Sampling Rate: 16000 Hz
# Processed 1184-86822-0081.wav - Sampling Rate: 16000 Hz
# Processed 1184-86822-0097.wav - Sampling Rate: 16000 Hz
# Processed 1184-86822-0104.wav - Sampling Rate: 16000 Hz
# Processed 1184-86822-0106.wav - Sampling Rate: 16000 Hz
# Processed 1184-86822-0107.wav - Sampling Rate: 16000 Hz
# Processed 1184-86822-0114.wav - Sampling Rate: 16000 Hz
# Processed 1184-86822-0119.wav - Sampling Rate: 16000 Hz
# Processed 1184-86823-0024.wav - Sampling Rate: 16000 Hz
# Processed 1184-86823-0039.wav - Sampling Rate: 16000 Hz
# Processed 1184-86823-0061.wav - Sampling Rate: 16000 Hz
# Processed 1184-86823-0066.wav - Sampling Rate: 16000 Hz
# Processed 1184-86823-0070.wav - Sampling Rate: 16000 Hz
# Processed 1184-86823-0078.wav - Sampling Rate: 16000 Hz

# %%
print(results)
# Out:
# {'1184-121024-0021.wav': (array([-71, -74, -75, ..., 125, 120, 111], dtype=int16), 16000), '1184-121024-0037.wav': (array([ -76,  -90, -100, ...,   20,   -5,    2], dtype=int16), 16000), '1184-121024-0090.wav': (array([-157, -167, -171, ...,  -40,  -37,  -43], dtype=int16), 16000), '1184-121024-0158.wav': (array([-671, -746, -809, ...,    7,    4,    1], dtype=int16), 16000), '1184-121024-0159.wav': (array([ -1,   1,   1, ..., -59, -63, -63], dtype=int16), 16000), '1184-121024-0160.wav': (array([ -60,  -67,  -71, ..., -239, -244, -244], dtype=int16), 16000), '1184-121024-0162.wav': (array([111, 133, 134, ...,  -3, -13, -16], dtype=int16), 16000), '1184-121024-0172.wav': (array([ 51,  71,  79, ..., -49, -46, -42], dtype=int16), 16000), '1184-121024-0173.wav': (array([ -32,  -31,  -36, ..., -124, -114, -107], dtype=int16), 16000), '1184-121024-0178.wav': (array([119, 118, 116, ..., -22, -27, -19], dtype=int16), 16000), '1184-121045-0004.wav': (array([106,  96,  67, ..., 104, 102, 101], dtype=int16), 16000), '1184-121045-0012.wav': (array([ -10, -112,  -14, ...,  -58,  -58,  -53], dtype=int16), 16000), '1184-121045-0017.wav': (array([-16, -14,  -7, ..., -28,  39, 442], dtype=int16), 16000), '1184-121045-0018.wav': (array([561, 589, 761, ...,  43,  48,  54], dtype=int16), 16000), '1184-121045-0024.wav': (array([ 85,  54,  38, ..., 116, 113, 119], dtype=int16), 16000), '1184-121045-0034.wav': (array([106, 112, 112, ...,  69, 147, 190], dtype=int16), 16000), '1184-121045-0035.wav': (array([ 165,  140,  114, ...,  970, 1514, 2367], dtype=int16), 16000), '1184-121045-0047.wav': (array([ 61,  60,  46, ..., -89,  -5, -23], dtype=int16), 16000), '1184-121045-0053.wav': (array([ 176,  192,  220, ...,  -66, -110,  -66], dtype=int16), 16000), '1184-121045-0062.wav': (array([ 428, 5619, -839, ...,  -84,  -70,  -57], dtype=int16), 16000), '1184-121045-0066.wav': (array([-726, -720, -756, ..., -125, -143, -182], dtype=int16), 16000), '1184-121045-0077.wav': (array([-175, -199, -179, ...,   17,   38,   42], dtype=int16), 16000), '1184-121045-0080.wav': (array([-2110,    -7,  1610, ...,  -215,  -207,  -219], dtype=int16), 16000), '1184-121050-0010.wav': (array([ 139,  180,  206, ..., -285, -311, -317], dtype=int16), 16000), '1184-121050-0018.wav': (array([  -5,  279,  376, ..., 1220, 1203, 1214], dtype=int16), 16000), '1184-121050-0027.wav': (array([507, 396, 442, ..., 168, 187, 196], dtype=int16), 16000), '1184-121050-0029.wav': (array([1063, 1070, 1097, ...,  992,  991, 1004], dtype=int16), 16000), '1184-86708-0002.wav': (array([  -5,   -7,   -7, ..., -170, -172, -174], dtype=int16), 16000), '1184-86708-0003.wav': (array([-171, -168, -166, ...,    1,    4,    6], dtype=int16), 16000), '1184-86708-0004.wav': (array([  8,  10,  13, ..., 126, 115, 101], dtype=int16), 16000), '1184-86708-0009.wav': (array([-2084, -1958, -1859, ...,  -145,  -141,  -147], dtype=int16), 16000), '1184-86708-0029.wav': (array([   50,    51,    52, ...,  -953, -1061, -1113], dtype=int16), 16000), '1184-86708-0031.wav': (array([ 24,  21,  17, ..., 226, 287, 344], dtype=int16), 16000), '1184-86708-0051.wav': (array([  92,   87,   83, ..., -297, -299, -301], dtype=int16), 16000), '1184-86708-0057.wav': (array([-156, -203,  421, ...,   31,   30,   24], dtype=int16), 16000), '1184-86708-0060.wav': (array([ 345, -154, -414, ...,   91,   90,   88], dtype=int16), 16000), '1184-86708-0063.wav': (array([-12, -12, -12, ...,   5,   4,   2], dtype=int16), 16000), '1184-86708-0064.wav': (array([ 1,  1, -2, ..., 11, 10, 10], dtype=int16), 16000), '1184-86708-0065.wav': (array([ 9,  9,  9, ..., -3, -5, -6], dtype=int16), 16000), '1184-86708-0077.wav': (array([   -1,    -1,     1, ..., -1156, -1120, -1053], dtype=int16), 16000), '1184-86708-0081.wav': (array([ 82,  81,  82, ..., -15,  -4,   3], dtype=int16), 16000), '1184-86708-0101.wav': (array([-136, -147, -155, ...,   51,    7,    2], dtype=int16), 16000), '1184-86710-0000.wav': (array([  1,   0,   1, ...,   4,  -1, -14], dtype=int16 ...

# %%
def load_json_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    return data

def write_to_json(new_data, file_path):
    with open(file_path, 'w', encoding='utf-8') as file:
        json.dump(new_data, file, indent=4)

# %%
res=[]
for file in results:
    a_array,s_rate = results[file][0],results[file][1]
    item={}
    item['filename']=file
    item['array']=a_array
    item['sampling_rate']=s_rate
    res.append(item)

write_to_json(res,'250_audio_array.json')
